# %%
import requests

# %%
r = requests.get('https://edusanjal.com/college/')

# %%
print(r.text)
# Out:
# <!DOCTYPE html><html  lang="en" data-capo=""><head><meta charset="utf-8">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <title>Colleges in Nepal - Edusanjal</title>
# <script src="https://www.googletagmanager.com/gtag/js?id=G-MJNNBE6XYD" async type="text/javascript"></script>
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(r.content, "html.parser")

# %%
soup.text
# Out:
# "\n\nColleges in Nepal - Edusanjal\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nOpen menu   \xa0MENU Edusanjal Sign in  Sign up  Courses  Colleges  Degrees  Exams  Schools  Admissions  News  Blogs  Skills More Schools  Scholarships  Disciplines  Vacancies  Careers  Events  Videos  Rankings  Posts  Councils  Organizations  Universities BBA BBA(Finance) & MBAAce Institute of Management Apply Bachelors Portal Visit Now Admission Counseling Visit Now Colleges in Nepal Filter Thames International CollegeTribhuvan UniversitySurya Bikram Gyawali Marg, Old Baneshwor, KathmanduTexas College of Management and ITLincoln University CollegeSiphal, KathmanduAce Institute of ManagementPokhara UniversityNew Baneshwor, KathmanduNCTTM - IST CollegeTribhuvan UniversityGyaneshwor, Opposite to German Embassy, KathmanduKathford International College of Engineering and ManagementTribhuvan UniversityBalkumari, LalitpurNepal College of Informati
# ...

# %%
soup.find_all('a')
# Out:
# [<a aria-label="menu" class="navbar-burger burger menu" role="button"><span aria-hidden="true"></span> <span aria-hidden="true"></span> <span aria-hidden="true"></span></a>,
#  <a class="" href="/"><span class="sr-only">Edusanjal</span><img alt="Edusanjal logo" class="w-auto h-8 sm:h-10 md:block mw-40" data-not-lazy="" height="46" src="/edusanjal-logo.svg" width="300"/></a>,
#  <a class="text-base font-medium text-gray-600 whitespace-nowrap hover:text-gray-900" href="/account/login/"> Sign in </a>,
#  <a class="inline-flex items-center justify-center px-4 py-2 text-base font-medium text-white border border-transparent rounded-md shadow-sm whitespace-nowrap bg-pr hover:bg-primary-light" href="/account/signup/"> Sign up </a>,
#  <a class="text-base font-medium text-gray-600 hover:text-gray-900" href="/course/"> Courses </a>,
# ...
